# %% [markdown]
# # Librairies

# %%
import pandas as pd
import numpy as np
import operator
import gzip
import networkx as nx
import time
import random
random.seed(10)

from node2vec import Node2Vec

import torch
import torch.nn as nn
from torch.nn import Linear
import torch.nn.functional as F

import torch_geometric
from torch_geometric.data import HeteroData
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, Linear, to_hetero

from sklearn.metrics import precision_score, recall_score, f1_score

from src.utils import *
from src.gnn import *

# %%
print(torch.__version__)
# Out:
# 1.13.1

# %%
print(torch_geometric.__version__)
# Out:
# 2.4.0

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %% [markdown]
# # OWL2Bench

# %%
OWL2Bench_dbs = [{'path' : './datasets/OWL2Bench/OWL2Bench1/',
                  'train_file' : '_train_OWL2Bench1',
                  'test_file' : '_test_OWL2Bench1'},
                 {'path' : './datasets/OWL2Bench/OWL2Bench2/',
                  'train_file' : '_train_OWL2Bench2',
                  'test_file' : '_test_OWL2Bench2'}]

# %%
for db_ in OWL2Bench_dbs:    
    path = db_['path']
    train_file = db_['train_file']
    test_file = db_['test_file']

    print('Running...', train_file, test_file)

    df_train = load_ore_files(path+train_file)
    df_train = df_train[df_train['p'] == 'SubClassOf']
    g_train, nodes_train, edges_train = create_graph(df_train)
    print(f'# Train - Triplets: {len(df_train)}, # Nodes/Classes: {g_train.number_of_nodes()}, # Edges: {g_train.number_of_edges()}')
    df_test = load_ore_files(path+test_file)
    df_test = df_test[df_test['p'] == 'SubClassOf']
    g_test, nodes_test, edges_test = create_graph(df_test)
    print(f'# Test - Triplets: {len(df_test)}, # Nodes/Classes: {g_test.number_of_nodes()}, # Edges: {g_test.number_of_edges()}')
    print()
    
    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()

    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT_2hops')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT_2hops')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()
# Out:
# Running... _train_OWL2Bench1 _test_OWL2Bench1
# # Train - Triplets: 105, # Nodes/Classes: 113, # Edges: 105
# # Test - Triplets: 30, # Nodes/Classes: 45, # Edges: 30
#
# GAT:
# Epoch: 0, Loss: 0.3855
# Epoch: 50, Loss: 0.1080
# Epoch: 100, Loss: 0.0991
# Epoch: 150, Loss: 0.0976
# Epoch: 200, Loss: 0.0859
# Epoch: 250, Loss: 0.0900
# Epoch: 300, Loss: 0.0717
# Epoch: 350, Loss: 0.0687
# Epoch: 400, Loss: 0.0610
# Epoch: 450, Loss: 0.0653
# Epoch: 500, Loss: 0.0763
# Epoch: 550, Loss: 0.0634
# Epoch: 600, Loss: 0.0584
# Epoch: 650, Loss: 0.0617
# Epoch: 700, Loss: 0.0643
# Epoch: 750, Loss: 0.0506
# Epoch: 800, Loss: 0.0522
# Precision: 0.500, Recall: 0.133, F1-Score: 0.211
#
# head, relation -> tail?
# hits@1: 0.100, hits@10: 0.333
# -------------------------------------------
# Run time: 4 seconds, 0 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.3506
# Epoch: 50, Loss: 0.1675
# Epoch: 100, Loss: 0.1327
# Epoch: 150, Loss: 0.1503
# Epoch: 200, Loss: 0.0972
# Epoch: 250, Loss: 0.0937
# Epoch: 300, Loss: 0.0795
# Epoch: 350, Loss: 0.0788
# Epoch: 400, Loss: 0.0905
# Epoch: 450, Loss: 0.0697
# Epoch: 500, Loss: 0.0837
# Epoch: 550, Loss: 0.0851
# Epoch: 600, Loss: 0.0676
# Epoch: 650, Loss: 0.0668
# Epoch: 700, Loss: 0.0726
# Epoch: 750, Loss: 0.0723
# Epoch: 800, Loss: 0.0849
# Precision: 0.333, Recall: 0.100, F1-Score: 0.154
#
# head, relation -> tail?
# hits@1: 0.100, hits@10: 0.433
# -------------------------------------------
# Run time: 5 seconds, 0 minutes
#
# Running... _train_OWL2Bench2 _test_OWL2Bench2
# # Train - Triplets: 105, # Nodes/Classes: 115, # Edges: 105
# # Test - Triplets: 30, # Nodes/Classes: 43, # Edges: 30
#
# GAT:
# Epoch: 0, Loss: 0.3960
# Epoch: 50, Loss: 0.1358
# Epoch: 100, Loss: 0.1106
# Epoch: 150, Loss: 0.1030
# Epoch: 200, Loss: 0.0997
# Epoch: 250, Loss: 0.0745
# Epoch: 300, Loss: 0.0756
# Epoch: 350, Loss: 0.0427
# Epoch: 400, Loss: 0.0584
# Epoch: 450, Loss: 0.0651
# Epoch: 500, Loss: 0.0464
# Epoch: 550, Loss: 0.0409
# Epoch: 600, Loss: 0.0361
# Epoch: 650, Loss: 0.0395
# Epoch: 700, Loss: 0.0321
# Epoch: 750, Loss: 0.0348
# Epoch: 800, Loss: 0.0440
# Precision: 0.727, Recall: 0.267, F1-Score: 0.390
#
# head, relation -> tail?
# hits@1: 0.267, hits@10: 0.467
# -------------------------------------------
# Run time: 5 seconds, 0 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.4161
# Epoch: 50, Loss: 0.2101
# Epoch: 100, Loss: 0.1216
# Epoch: 150, Loss: 0.1172
# Epoch: 200, Loss: 0.0925
# Epoch: 250, Loss: 0.0868
# Epoch: 300, Loss: 0.0943
# Epoch: 350, Loss: 0.0811
# Epoch: 400, Loss: 0.0859
# Epoch: 450, Loss: 0.0801
# Epoch: 500, Loss: 0.0851
# Epoch: 550, Loss: 0.0791
# Epoch: 600, Loss: 0.0812
# Epoch: 650, Loss: 0.0779
# Epoch: 700, Loss: 0.0742
# Epoch: 750, Loss: 0.0828
# Epoch: 800, Loss: 0.0712
# Precision: 0.385, Recall: 0.167, F1-Score: 0.233
#
# head, relation -> tail?
# hits@1: 0.000, hits@10: 0.267
# -------------------------------------------
# Run time: 4 seconds, 0 minutes

# %% [markdown]
# # ORE

# %%
ORE_dbs = [{'path' : './datasets/ORE/ORE1/',
            'train_file' : '_train_ORE1',
            'test_file' : '_test_ORE1'},
           {'path' : './datasets/ORE/ORE2/',
            'train_file' : '_train_ORE2',
            'test_file' : '_test_ORE2'},
           {'path' : './datasets/ORE/ORE3/',
            'train_file' : '_train_ORE3',
            'test_file' : '_test_ORE3'}]

# %%
for db_ in ORE_dbs:    
    path = db_['path']
    train_file = db_['train_file']
    test_file = db_['test_file']

    print('Running...', train_file, test_file)

    df_train = load_ore_files(path+train_file)
    df_train = df_train[df_train['p'] == 'SubClassOf']
    g_train, nodes_train, edges_train = create_graph(df_train)
    print(f'# Train - Triplets: {len(df_train)}, # Nodes/Classes: {g_train.number_of_nodes()}, # Edges: {g_train.number_of_edges()}')
    df_test = load_ore_files(path+test_file)
    df_test = df_test[df_test['p'] == 'SubClassOf']
    g_test, nodes_test, edges_test = create_graph(df_test)
    print(f'# Test - Triplets: {len(df_test)}, # Nodes/Classes: {g_test.number_of_nodes()}, # Edges: {g_test.number_of_edges()}')
    print()

    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()

    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT_2hops')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT_2hops')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()
# Out:
# Running... _train_ORE1 _test_ORE1
# # Train - Triplets: 8194, # Nodes/Classes: 6654, # Edges: 8194
# # Test - Triplets: 2342, # Nodes/Classes: 3052, # Edges: 2342
#
# GAT:
# Epoch: 0, Loss: 0.3287
# Epoch: 50, Loss: 0.2361
# Epoch: 100, Loss: 0.2224
# Epoch: 150, Loss: 0.2202
# Epoch: 200, Loss: 0.2172
# Epoch: 250, Loss: 0.2196
# Epoch: 300, Loss: 0.2120
# Epoch: 350, Loss: 0.2144
# Epoch: 400, Loss: 0.2115
# Epoch: 450, Loss: 0.2111
# Epoch: 500, Loss: 0.2106
# Epoch: 550, Loss: 0.2114
# Epoch: 600, Loss: 0.2074
# Epoch: 650, Loss: 0.2099
# Epoch: 700, Loss: 0.2101
# Epoch: 750, Loss: 0.2101
# Epoch: 800, Loss: 0.2071
# Precision: 0.572, Recall: 0.267, F1-Score: 0.364
#
# head, relation -> tail?
# hits@1: 0.013, hits@10: 0.091
# -------------------------------------------
# Run time: 118 seconds, 2 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.3406
# Epoch: 50, Loss: 0.2720
# Epoch: 100, Loss: 0.2490
# Epoch: 150, Loss: 0.2283
# Epoch: 200, Loss: 0.2240
# Epoch: 250, Loss: 0.2227
# Epoch: 300, Loss: 0.2212
# Epoch: 350, Loss: 0.2201
# Epoch: 400, Loss: 0.2192
# Epoch: 450, Loss: 0.2186
# Epoch: 500, Loss: 0.2193
# Epoch: 550, Loss: 0.2178
# Epoch: 600, Loss: 0.2171
# Epoch: 650, Loss: 0.2233
# Epoch: 700, Loss: 0.2173
# Epoch: 750, Loss: 0.2170
# Epoch: 800, Loss: 0.2166
# Precision: 0.574, Recall: 0.207, F1-Score: 0.304
#
# head, relation -> tail?
# hits@1: 0.012, hits@10: 0.064
# -------------------------------------------
# Run time: 136 seconds, 2 minutes
#
# Running... _train_ORE2 _test_ORE2
# # Train - Triplets: 8204, # Nodes/Classes: 6650, # Edges: 8204
# # Test - Triplets: 2344, # Nodes/Classes: 3102, # Edges: 2344
#
# GAT:
# Epoch: 0, Loss: 0.3213
# Epoch: 50, Loss: 0.2382
# Epoch: 100, Loss: 0.2202
# Epoch: 150, Loss: 0.2169
# Epoch: 200, Loss: 0.2169
# Epoch: 250, Loss: 0.2145
# Epoch: 300, Loss: 0.2116
# Epoch: 350, Loss: 0.2126
# Epoch: 400, Loss: 0.2118
# Epoch: 450, Loss: 0.2122
# Epoch: 500, Loss: 0.2099
# Epoch: 550, Loss: 0.2091
# Epoch: 600, Loss: 0.2115
# Epoch: 650, Loss: 0.2079
# Epoch: 700, Loss: 0.2082
# Epoch: 750, Loss: 0.2063
# Epoch: 800, Loss: 0.2065
# Precision: 0.555, Recall: 0.328, F1-Score: 0.412
#
# head, relation -> tail?
# hits@1: 0.019, hits@10: 0.093
# -------------------------------------------
# Run time: 117 seconds, 2 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.3402
# Epoch: 50, Loss: 0.2799
# Epoch: 100, Loss: 0.2366
# Epoch: 150, Loss: 0.2297
# Epoch: 200, Loss: 0.2253
# Epoch: 250, Loss: 0.2471
# Epoch: 300, Loss: 0.2451
# Epoch: 350, Loss: 0.2487
# Epoch: 400, Loss: 0.2383
# Epoch: 450, Loss: 0.2414
# Epoch: 500, Loss: 0.2406
# Epoch: 550, Loss: 0.2396
# Epoch: 600, Loss: 0.2360
# Epoch: 650, Loss: 0.2340
# Epoch: 700, Loss: 0.2339
# Epoch: 750, Loss: 0.2316
# Epoch: 800, Loss: 0.2300
# Precision: 0.528, Recall: 0.207, F1-Score: 0.298
#
# head, relation -> tail?
# hits@1: 0.013, hits@10: 0.081
# -------------------------------------------
# Run time: 134 seconds, 2 minutes
#
# Running... _train_ORE3 _test_ORE3
# # Train - Triplets: 8187, # Nodes/Classes: 6673, # Edges: 8187
# # Test - Triplets: 2340, # Nodes/Classes: 3045, # Edges: 2340
#
# GAT:
# Epoch: 0, Loss: 0.3194
# Epoch: 50, Loss: 0.2344
# Epoch: 100, Loss: 0.2216
# Epoch: 150, Loss: 0.2180
# Epoch: 200, Loss: 0.2153
# Epoch: 250, Loss: 0.2146
# Epoch: 300, Loss: 0.2133
# Epoch: 350, Loss: 0.2119
# Epoch: 400, Loss: 0.2149
# Epoch: 450, Loss: 0.2099
# Epoch: 500, Loss: 0.2118
# Epoch: 550, Loss: 0.2095
# Epoch: 600, Loss: 0.2086
# Epoch: 650, Loss: 0.2120
# Epoch: 700, Loss: 0.2088
# Epoch: 750, Loss: 0.2076
# Epoch: 800, Loss: 0.2099
# Precision: 0.621, Recall: 0.195, F1-Score: 0.297
#
# head, relation -> tail?
# hits@1: 0.016, hits@10: 0.088
# -------------------------------------------
# Run time: 118 seconds, 2 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.3308
# Epoch: 50, Loss: 0.2816
# Epoch: 100, Loss: 0.2340
# Epoch: 150, Loss: 0.2296
# Epoch: 200, Loss: 0.2290
# Epoch: 250, Loss: 0.2251
# Epoch: 300, Loss: 0.2225
# Epoch: 350, Loss: 0.2252
# Epoch: 400, Loss: 0.2249
# Epoch: 450, Loss: 0.2227
# Epoch: 500, Loss: 0.2203
# Epoch: 550, Loss: 0.2251
# Epoch: 600, Loss: 0.2235
# Epoch: 650, Loss: 0.2200
# Epoch: 700, Loss: 0.2215
# Epoch: 750, Loss: 0.2195
# Epoch: 800, Loss: 0.2199
# Precision: 0.596, Recall: 0.113, F1-Score: 0.190
#
# head, relation -> tail?
# hits@1: 0.015, hits@10: 0.072
# -------------------------------------------
# Run time: 136 seconds, 2 minutes

# %% [markdown]
# # CaLiGraph

# %%
CLG_dbs = [{'path' : './datasets/clg/clg_10e4/',
            'train_file' : 'clg_10e4-train.nt',
            'test_file' : 'clg_10e4-test.nt'},
           {'path' : './datasets/clg/clg_10e5/',
            'train_file' : 'clg_10e5-train.nt',
            'test_file' : 'clg_10e5-test.nt'}]

# %%
for db_ in CLG_dbs:
    path = db_['path']
    train_file = db_['train_file']
    test_file = db_['test_file']

    print('Running...', train_file, test_file)

    df_train = load_clg_files(path+train_file)
    df_train = df_train[df_train['p'] == '<http://www.w3.org/2000/01/rdf-schema#subClassOf>']
    g_train, nodes_train, edges_train = create_graph(df_train)
    print(f'# Train - Triplets: {len(df_train)}, # Nodes/Classes: {g_train.number_of_nodes()}, # Edges: {g_train.number_of_edges()}')
    df_test = load_clg_files(path+test_file)
    df_test = df_test[df_test['p'] == '<http://www.w3.org/2000/01/rdf-schema#subClassOf>']
    g_test, nodes_test, edges_test = create_graph(df_test)
    print(f'# Test - Triplets: {len(df_test)}, # Nodes/Classes: {g_test.number_of_nodes()}, # Edges: {g_test.number_of_edges()}')
    print()

    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()

    st = time.time()
    model = GNN()
    model._train(g_train, 'GAT_2hops')
    model._eval(g_test, min(g_test.number_of_nodes(),100), 'GAT_2hops')
    et = time.time()
    elapsed_time = et - st
    print(f'Run time: {elapsed_time:.0f} seconds, {elapsed_time/60:.0f} minutes')
    print()
# Out:
# Running... clg_10e4-train.nt clg_10e4-test.nt
# # Train - Triplets: 59956, # Nodes/Classes: 10311, # Edges: 59956
# # Test - Triplets: 17132, # Nodes/Classes: 7866, # Edges: 17132
#
# GAT:
# Epoch: 0, Loss: 0.3498
# Epoch: 50, Loss: 0.1954
# Epoch: 100, Loss: 0.1636
# Epoch: 150, Loss: 0.1653
# Epoch: 200, Loss: 0.1612
# Epoch: 250, Loss: 0.1625
# Epoch: 300, Loss: 0.1573
# Epoch: 350, Loss: 0.1558
# Epoch: 400, Loss: 0.1577
# Epoch: 450, Loss: 0.1583
# Epoch: 500, Loss: 0.1572
# Epoch: 550, Loss: 0.1552
# Epoch: 600, Loss: 0.1680
# Epoch: 650, Loss: 0.1542
# Epoch: 700, Loss: 0.1523
# Epoch: 750, Loss: 0.1533
# Epoch: 800, Loss: 0.1550
# Precision: 0.814, Recall: 0.648, F1-Score: 0.721
#
# head, relation -> tail?
# hits@1: 0.306, hits@10: 0.523
# -------------------------------------------
# Run time: 599 seconds, 10 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.2596
# Epoch: 50, Loss: 0.1841
# Epoch: 100, Loss: 0.1748
# Epoch: 150, Loss: 0.1771
# Epoch: 200, Loss: 0.1759
# Epoch: 250, Loss: 0.1751
# Epoch: 300, Loss: 0.1728
# Epoch: 350, Loss: 0.1723
# Epoch: 400, Loss: 0.1740
# Epoch: 450, Loss: 0.1710
# Epoch: 500, Loss: 0.1722
# Epoch: 550, Loss: 0.1708
# Epoch: 600, Loss: 0.1708
# Epoch: 650, Loss: 0.1699
# Epoch: 700, Loss: 0.1683
# Epoch: 750, Loss: 0.1694
# Epoch: 800, Loss: 0.1685
# Precision: 0.907, Recall: 0.292, F1-Score: 0.442
#
# head, relation -> tail?
# hits@1: 0.098, hits@10: 0.231
# -------------------------------------------
# Run time: 663 seconds, 11 minutes
#
# Running... clg_10e5-train.nt clg_10e5-test.nt
# # Train - Triplets: 96273, # Nodes/Classes: 75195, # Edges: 96273
# # Test - Triplets: 27508, # Nodes/Classes: 26675, # Edges: 27508
#
# GAT:
# Epoch: 0, Loss: 0.3529
# Epoch: 50, Loss: 0.1431
# Epoch: 100, Loss: 0.1308
# Epoch: 150, Loss: 0.1164
# Epoch: 200, Loss: 0.1083
# Epoch: 250, Loss: 0.1065
# Epoch: 300, Loss: 0.1007
# Epoch: 350, Loss: 0.1059
# Epoch: 400, Loss: 0.0970
# Epoch: 450, Loss: 0.0974
# Epoch: 500, Loss: 0.1087
# Epoch: 550, Loss: 0.1052
# Epoch: 600, Loss: 0.1015
# Epoch: 650, Loss: 0.1066
# Epoch: 700, Loss: 0.1012
# Epoch: 750, Loss: 0.1014
# Epoch: 800, Loss: 0.1057
# Precision: 1.000, Recall: 0.000, F1-Score: 0.000
#
# head, relation -> tail?
# hits@1: 0.667, hits@10: 0.672
# -------------------------------------------
# Run time: 1618 seconds, 27 minutes
#
# GAT_2hops:
# Epoch: 0, Loss: 0.3942
# Epoch: 50, Loss: 0.1779
# Epoch: 100, Loss: 0.1164
# Epoch: 150, Loss: 0.1130
# Epoch: 200, Loss: 0.1175
# Epoch: 250, Loss: 0.1131
# Epoch: 300, Loss: 0.1133
# Epoch: 350, Loss: 0.1177
# Epoch: 400, Loss: 0.1124
# Epoch: 450, Loss: 0.1157
# Epoch: 500, Loss: 0.1128
# Epoch: 550, Loss: 0.1126
# Epoch: 600, Loss: 0.1130
# Epoch: 650, Loss: 0.1128
# Epoch: 700, Loss: 0.1129
# Epoch: 750, Loss: 0.1130
# Epoch: 800, Loss: 0.1125
# Precision: 0.745, Recall: 0.281, F1-Score: 0.408
#
# head, relation -> tail?
# hits@1: 0.000, hits@10: 0.003
# -------------------------------------------
# Run time: 1693 seconds, 28 minutes
